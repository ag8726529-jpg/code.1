# %%
abhi=[1,2,3]
print(abhi)
a=10
b=10
c=a+b
print(c)
# Out:
# [1, 2, 3]
# 20

# %%
a=10
b=20
c=a+b
print(c)
# Out:
# 30

# %%
while True:
    print("\n===========ATM MENU========")
    print("1.check balance")
    print("2.deposit Money")
    print("3.withdrawl Money")
    print("4.Exit")
    choice =int(input("enter your choice"))
    match choice:
        case 1:
            print("your balance is:",balance)
        case 2:
            amount=int(input("Enter Deposit Ammount:"))
            balance +=amount
            print("Amount Deposit sucessfully")
        case 3:
            amount=int(input("Enter your Withdrawl Ammount"))
            if amount<=balance:   
                balance -=amount
                print("please collect your case")
                print("Remaning Balance",balance)
            else:
                print("ensuffucient Balance")    


        case 4:
            print("Thankue for using ATM")
            break
        case _:
            print("envalid choose pleas try again")
